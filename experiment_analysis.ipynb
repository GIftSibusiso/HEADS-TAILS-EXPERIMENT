# %%
import pandas as pd
import visuals

# %% [markdown]
# # Tossing a coin 100 times, relative frequency explained

# %% [markdown]
# What happens when tossing a coin 100 times? In this experiment we'll be looking at indepth definition of relative frequency(also known as emperical/theoretical probabiity). When a fair coin is flipped it can land on either head or tail(2 mutually exclusive events) making the theoretical probability of the coin landing on head/tail 1/2 or 50%.
#
# Relative frequency is equal to the number of times an event happens divided by the number of trials, e.g if I was to toss a coin 10 times and record the results as 7 heads and 3 tails the relative frequency of getting heads according to the results will be 7/10 which is 70%. Unfortunately I was unable to get people who will toss a coin 100 times so instead I made a program that will toss a coin on their behalf and record the results.

# %% [markdown]
# ## Experiment results

# %% [markdown]
# **The code generates random results not my desired results, the code is available in this repository(data_generator.py) for reviews and  below are the recorded results(you can also play around with the code to observe the results yourself).**

# %%
df = pd.read_csv("data\experiment_outcome.csv")

df
# Out:
#     Trials  Heads  Tails
# 0        1   47.0   53.0
# 1        2   58.0   42.0
# 2        3   47.0   53.0
# 3        4   44.0   56.0
# 4  Average   49.0   51.0

# %% [markdown]
# There are 4 trials and in each trial a coin is flipped 100 times meaning the number of heads and tails in each trial are complimentary, the average of the data simply looks at what happens when a coin is tossed over 100 time.

# %% [markdown]
# In most cases the theoretical probability is close to the theoretical probability. In this experiment I was able to find a range of the relative frequency when a coin is tossed 100 times.

# %%
visuals.plt.figure(dpi=120)
visuals.graph_representation()

# %% [markdown]
# After running and observing the code a number of times I am able to conclude that when a coin is tossed 100 times the number of heads and tails will range between 40 and 60 making the relative frequency to be greater than 40% but lesser than 60% inclusive, which is close to the coins theoretical probability of 50%. The more you toss the coin the closer the relative frequency is to the theoretical probability and also the range becomes smaller.
